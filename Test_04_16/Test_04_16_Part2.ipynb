# %%
import pandas as pd
DataFrame = pd.read_csv('C:\\Users\\Naray\\Auto.csv')
DataFrame.head(5)
# Out:
#    Unnamed: 0  symboling  normalized_losses         make fuel_type aspiration  \
# 0           0          3                NaN  alfa-romero       gas        std
# 1           1          3                NaN  alfa-romero       gas        std
# 2           2          1                NaN  alfa-romero       gas        std
# 3           3          2              164.0         audi       gas        std
# 4           4          2              164.0         audi       gas        std
#
#   num_doors   body_style drive_wheels engine_location  ...  engine_size  \
# 0       two  convertible          rwd           front  ...          130
# 1       two  convertible          rwd           front  ...          130
# 2       two    hatchback          rwd           front  ...          152
# 3      four        sedan          fwd           front  ...          109
# 4      four        sedan          4wd           front  ...          136
#
# ...

# %%
Answer = DataFrame[['make']][DataFrame.price==DataFrame['price'].max()]
Answer
# Out:
#              make
# 74  mercedes-benz

# %%
DataFrame['make'].value_counts()
# Out:
# toyota           32
# nissan           18
# mazda            17
# mitsubishi       13
# honda            13
# volkswagen       12
# subaru           12
# peugot           11
# volvo            11
# dodge             9
# mercedes-benz     8
# bmw               8
# audi              7
# plymouth          7
# saab              6
# porsche           5
# isuzu             4
# jaguar            3
# chevrolet         3
# alfa-romero       3
# renault           2
# mercury           1
# Name: make, dtype: int64

# %%
car_brand = DataFrame.groupby('make')
DataFrame = car_brand['make','price'].max()
DataFrame
# Out:
# C:\Users\naray\AppData\Local\Temp/ipykernel_10716/1238104809.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   DataFrame = car_brand['make','price'].max()
#                         make    price
# make
# alfa-romero      alfa-romero  16500.0
# audi                    audi  23875.0
# bmw                      bmw  41315.0
# chevrolet          chevrolet   6575.0
# dodge                  dodge  12964.0
# honda                  honda  12945.0
# isuzu                  isuzu  11048.0
# jaguar                jaguar  36000.0
# mazda                  mazda  18344.0
# mercedes-benz  mercedes-benz  45400.0
# mercury              mercury  16503.0
# mitsubishi        mitsubishi  14869.0
# nissan                nissan  19699.0
# peugot                peugot  18150.0
# plymouth            plymouth  12764.0
# porsche              porsche  37028.0
# renault              renault   9895.0
# ...

# %%
Answer = DataFrame.sort_values(by=['price'], ascending=False)
Answer
# Out:
#                         make    price
# make
# mercedes-benz  mercedes-benz  45400.0
# bmw                      bmw  41315.0
# porsche              porsche  37028.0
# jaguar                jaguar  36000.0
# audi                    audi  23875.0
# volvo                  volvo  22625.0
# nissan                nissan  19699.0
# saab                    saab  18620.0
# mazda                  mazda  18344.0
# peugot                peugot  18150.0
# toyota                toyota  17669.0
# mercury              mercury  16503.0
# alfa-romero      alfa-romero  16500.0
# mitsubishi        mitsubishi  14869.0
# volkswagen        volkswagen  13845.0
# dodge                  dodge  12964.0
# honda                  honda  12945.0
# plymouth            plymouth  12764.0
# subaru                subaru  11694.0
# isuzu                  isuzu  11048.0
# renault              renault   9895.0
# chevrolet          chevrolet   6575.0

# %%
Answer=DataFrame.groupby(['make','fuel_type','body_style'])['city_mpg','highway_mpg'].mean()
Answer
# Out:
# C:\Users\naray\AppData\Local\Temp/ipykernel_10716/2241800484.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   Answer=DataFrame.groupby(['make','fuel_type','body_style'])['city_mpg','highway_mpg'].mean()
#                                     city_mpg  highway_mpg
# make        fuel_type body_style
# alfa-romero gas       convertible  21.000000    27.000000
#                       hatchback    19.000000    26.000000
# audi        gas       hatchback    16.000000    22.000000
#                       sedan        19.400000    24.400000
#                       wagon        19.000000    25.000000
# ...                                      ...          ...
# volkswagen  gas       sedan        25.200000    31.600000
#                       wagon        25.000000    31.000000
# volvo       diesel    sedan        26.000000    27.000000
#             gas       sedan        20.428571    25.571429
# ...
